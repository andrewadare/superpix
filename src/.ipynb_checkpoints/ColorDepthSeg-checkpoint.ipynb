# %%
# push!(LOAD_PATH, joinpath(splitdir(pwd())[1], "src"))

# %%
# workspace()
# reload("SuperPix")
# using Images
# using SuperPix
# include("/Users/adare/repos/superpix/src/SuperPix.jl")

using Images
using Color
using LightGraphs
using Reactive, Interact

include("grids.jl")
include("means.jl")
include("prep.jl")
include("rag.jl")
include("recombine.jl")
include("slic.jl")
include("vis.jl")
# Out:
# segment_overlay (generic function with 1 method)

# %%
row_range = 91:380;
col_range = 101:800;

# %%
# imrgb = imread("../imgs/color_1.jpg")
# rgbsub = subim(imrgb, "x", col_range, "y", row_range) 
# show(map(Float32, separate(imrgb["x", col_range, "y", row_range])))

# %%
imrgb = imread("../imgs/color_1.jpg")

# Convert to CIELAB color space for improved gradients and color distances.
imlab = convert(Image{Color.LAB}, map(Float32, separate(imrgb["x", col_range, "y", row_range])))
imlab.properties["spatialorder"] = ["x","y"]

show(imlab)
imlab
# Out:
# Lab Images.Image with:
#   data: 700x290 Array{Color.Lab{Float32},2}
#   properties:
#     timedim: 0
#     spatialorder:  x y
#     pixelspacing:  1.0 1.0
# Lab Images.Image with:
#   data: 700x290 Array{Color.Lab{Float32},2}
#   properties:
#     timedim: 0
#     spatialorder:  x y
#     pixelspacing:  1.0 1.0

# %%
imdep = imread("../imgs/depth_1.png")
dep = convert(Array, map(Float32, separate(imdep["x", col_range, "y", row_range])))
dep = reshape(dep, nr, nc)

println("min, max = ", minimum(dep), " ", maximum(dep))
grayim(dep)
# Out:
# min, max = 0.0 0.21759365
# Gray Images.Image with:
#   data: 700x290 Array{Float32,2}
#   properties:
#     colorspace: Gray
#     spatialorder:  x y

# %%
for i=1:10
    mindep = minimum(dep[dep .> 0])
    dep = clamp(dep, mindep, maximum(dep)) - mindep
    dep /= maximum(dep)
end

println("min, max = ", minimum(dep), " ", maximum(dep))
grayim(dep)
# Out:
# min, max = 0.0 1.0
# Gray Images.Image with:
#   data: 700x290 Array{Float32,2}
#   properties:
#     colorspace: Gray
#     spatialorder:  x y

# %%
gx, gy = imgradients(imlab, "prewitt")
gradmag = magnitude(data(gx),data(gy))
gradmax = reshape(maximum(gradmag, colordim(gx)), tuple(size_spatial(gx)...))
grayim(sc(gradmax))
# Out:
# Gray Images.Image with:
#   data: 700x290 Array{FixedPointNumbers.UfixedBase{UInt8,8},2}
#   properties:
#     colorspace: Gray
#     spatialorder:  x y

# %%
nr, nc = size(imlab)

# Approximate number of requested superpixels.
k = 1000

# Cluster compactness parameter. 
# Large m favors roundness and uniformity (hex cells as m -> ∞)
# Small m favors color edge adherence.
# Note: k and m are coupled, since the clustering distance is a quadrature
# sum of spatial_distance/s and color_distance/m where s = sqrt(h*w/k).
m = 10# Seed the clusters

grid = hexgrid(nr, nc, k);

# Shift grid points slightly away from edges
centers = adjusted_grid(grid, gradmax);

# %%
@time labels, nlabels = slic(imlab, centers, k, m, niter=5)
grayim(sc(labels))
# Out:
# Dist calcs 1...elapsed time: 0.195085441 seconds
# Cluster repositioning 1...elapsed time: 0.001938093 seconds
# Dist calcs 2...elapsed time: 0.230530071 seconds
# Cluster repositioning 2...elapsed time: 0.001617842 seconds
# Dist calcs 3...elapsed time: 0.168290231 seconds
# Cluster repositioning 3...elapsed time: 0.001633683 seconds
# Dist calcs 4...elapsed time: 0.163920656 seconds
# Cluster repositioning 4...elapsed time: 0.00148505 seconds
# Dist calcs 5...elapsed time: 0.173714093 seconds
# Cluster repositioning 5...elapsed time: 0.001665346 seconds
# elapsed time: 1.057431867 seconds (1141 MB allocated, 19.74% gc time in 52 pauses with 1 full sweep)
# Gray Images.Image with:
#   data: 700x290 Array{FixedPointNumbers.UfixedBase{UInt8,8},2}
#   properties:
#     colorspace: Gray
#     spatialorder:  x y

# %%
lab_means, color_superpix = color_means(imlab, labels, nlabels)
dep_means, depth_superpix = color_means(dep, labels, nlabels)
convert(Image{Color.RGB}, color_superpix)
# Out:
# RGB Images.Image with:
#   data: 700x290 Array{Color.RGB{Float32},2}
#   properties:
#     timedim: 0
#     spatialorder:  x y
#     pixelspacing:  1.0 1.0

# %%
grayim(depth_superpix)
# Out:
# Gray Images.Image with:
#   data: 700x290 Array{Float32,2}
#   properties:
#     colorspace: Gray
#     spatialorder:  x y

# %%
graph, edgewts, borders = adjacency_graph(labels, nlabels, lab_means, dep_means);
centroids = cluster_centroids(labels, nlabels);

# %%
# seg_labels, nsegments = merged_superpixels(labels, graph);
# seg_lab_means, color_segments = color_means(imlab, seg_labels, nsegments);
# seg_dep_means, depth_segments = color_means(dep, seg_labels, nsegments);

# %%
@manipulate for t = 0.0:0.01:0.1, w = 0.0:0.1:1.0
    graph, edgewts, borders = adjacency_graph(labels, nlabels, lab_means, dep_means, depth_weight=w)
    g = cut_graph(graph, edgewts, t)
    seg_labels, nsegments = merged_superpixels(labels, g)

    seg_lab_means, color_segments = color_means(imlab, seg_labels, nsegments)
    seg_borders = segment_borders(seg_labels, color_segments)
    
    convert(Image{Color.RGB}, color_segments)
end
# Out:
# Interact.Slider{Float64}([Reactive.Input{Float64}] 0.05,"t",0.05,0.0:0.01:0.1)
# Interact.Slider{Float64}([Reactive.Input{Float64}] 0.5,"w",0.5,0.0:0.1:1.0)
# RGB Images.Image with:
#   data: 700x290 Array{Color.RGB{Float32},2}
#   properties:
#     timedim: 0
#     spatialorder:  x y
#     pixelspacing:  1.0 1.0

# %%
# @manipulate for t = 0.0:0.01:0.1
#     g = cut_graph(graph, edgewts, t)
#     seg_labels, nsegments = merged_superpixels(labels, g)

#     seg_lab_means, color_segments = color_means(imlab, seg_labels, nsegments)
#     seg_borders = segment_borders(seg_labels, color_segments);
#     convert(Image{Color.RGB}, seg_borders)
# end

@manipulate for t = 0.0:0.01:0.1, w = 0.0:0.1:1.0
    graph, edgewts, borders = adjacency_graph(labels, nlabels, lab_means, dep_means, depth_weight=w)
    g = cut_graph(graph, edgewts, t)
    seg_labels, nsegments = merged_superpixels(labels, g)

    seg_lab_means, color_segments = color_means(imlab, seg_labels, nsegments)
#     seg_borders = segment_borders(seg_labels, color_segments);
    seg_img = segment_overlay(seg_labels, imlab, color_segments, cluster_centroids(seg_labels, nsegments))
    convert(Image{Color.RGB}, seg_img)
end
# Out:
# Interact.Slider{Float64}([Reactive.Input{Float64}] 0.05,"t",0.05,0.0:0.01:0.1)
# Interact.Slider{Float64}([Reactive.Input{Float64}] 0.5,"w",0.5,0.0:0.1:1.0)
# RGB Images.Image with:
#   data: 700x290 Array{Color.RGB{Float32},2}
#   properties:
#     timedim: 0
#     spatialorder:  x y
#     pixelspacing:  1.0 1.0

# %%
@manipulate for t = 0.0:0.01:0.1
    g = cut_graph(graph, edgewts, t)
    seg_labels, nsegments = merged_superpixels(labels, g)

    seg_lab_means, color_segments = color_means(imlab, seg_labels, nsegments)
    seg_borders = segment_borders(seg_labels, color_segments);
#     convert(Image{Color.RGB}, seg_borders)

    graph_edges = graph_image(g, centroids, nr, nc)
#     centroid_img = zeros(labels);
    for c in 1:nlabels
        row, col = centroids[c, 1], centroids[c, 2]
        if (1 <= row <= nr) && (1 <= col <= nc)
            graph_edges[row, col] = 1
        end
    end

#     graph_edges = graph_image(g, centroids, nr, nc)
    grayim(graph_edges)
    
#     OverlayImage((borders', graph_edges', centroid_img'),
#                     (Color.RGB(0.2,0.2,0.2), Color.RGB(0,0.5,1), Color.RGB(1,1,0)),
#                     ((0,1), (0,1), (0,1))
#                     )
end
# Out:
# Interact.Slider{Float64}([Reactive.Input{Float64}] 0.05,"t",0.05,0.0:0.01:0.1)
# Gray Images.Image with:
#   data: 700x290 Array{Float64,2}
#   properties:
#     colorspace: Gray
#     spatialorder:  x y
